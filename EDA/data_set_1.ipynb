# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/sleep_apnea_severity_dataset.csv")

# %%
df.head()
# Out:
#   Patient_ID  Age  Gender  Heart_Rate_bpm  SpO2_percent  Body_Temperature_C  \
# 0    P103107   34    Male              63          94.5                36.6
# 1    P106162   50  Female              98          85.5                37.0
# 2    P101868   33    Male              80          95.9                37.0
# 3    P103239   53  Female              62          93.6                36.2
# 4    P105510   44  Female             104          88.7                36.7
#
#    ECG_RR_Interval_ms  Respiration_Rate_bpm  Systolic_BP_mmHg  \
# 0                 928                    16               124
# 1                 685                    24               148
# 2                 772                    18               132
# 3                 949                    17               129
# 4                 631                    24               147
#
#    Diastolic_BP_mmHg Activity_Level  AHI_Index_per_hour Apnea_Severity  \
# ...

# %%
df.tail()
# Out:
#      Patient_ID  Age  Gender  Heart_Rate_bpm  SpO2_percent  \
# 6495    P103773   53  Female              87          90.4
# 6496    P105192   61  Female              89          83.2
# 6497    P105227   74  Female             101          80.3
# 6498    P105391   58    Male              91          83.6
# 6499    P100861   38    Male              63          96.6
#
#       Body_Temperature_C  ECG_RR_Interval_ms  Respiration_Rate_bpm  \
# 6495                36.3                 694                    19
# 6496                36.3                 729                    23
# 6497                36.3                 634                    29
# 6498                36.4                 608                    19
# 6499                36.4                 938                    13
#
#       Systolic_BP_mmHg  Diastolic_BP_mmHg Activity_Level  AHI_Index_per_hour  \
# 6495               129                 82        Resting                22.6
# ...

# %%
df.shape
# Out:
# (6500, 14)

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Heart_Rate_bpm', 'SpO2_percent',
#        'Body_Temperature_C', 'ECG_RR_Interval_ms', 'Respiration_Rate_bpm',
#        'Systolic_BP_mmHg', 'Diastolic_BP_mmHg', 'Activity_Level',
#        'AHI_Index_per_hour', 'Apnea_Severity', 'Model_Confidence'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Patient_ID            6500 non-null   object
#  1   Age                   6500 non-null   int64
#  2   Gender                6500 non-null   object
#  3   Heart_Rate_bpm        6500 non-null   int64
#  4   SpO2_percent          6500 non-null   float64
#  5   Body_Temperature_C    6500 non-null   float64
#  6   ECG_RR_Interval_ms    6500 non-null   int64
#  7   Respiration_Rate_bpm  6500 non-null   int64
#  8   Systolic_BP_mmHg      6500 non-null   int64
#  9   Diastolic_BP_mmHg     6500 non-null   int64
#  10  Activity_Level        6500 non-null   object
#  11  AHI_Index_per_hour    6500 non-null   float64
#  12  Apnea_Severity        6500 non-null   object
#  13  Model_Confidence      6500 non-null   float64
# dtypes: float64(4), int64(6), object(4)
# ...

# %%
df.describe()
# Out:
#                Age  Heart_Rate_bpm  SpO2_percent  Body_Temperature_C  \
# count  6500.000000     6500.000000   6500.000000         6500.000000
# mean     48.478615       80.180615     90.978200           36.689723
# std      12.770140       11.948587      5.404563            0.259206
# min      22.000000       50.000000     74.100000           35.800000
# 25%      39.000000       71.000000     87.200000           36.500000
# 50%      48.000000       79.000000     91.900000           36.700000
# 75%      57.000000       88.000000     95.700000           36.900000
# max      78.000000      121.000000    100.000000           37.700000
#
#        ECG_RR_Interval_ms  Respiration_Rate_bpm  Systolic_BP_mmHg  \
# count         6500.000000           6500.000000       6500.000000
# mean           764.383231             18.384000        129.564923
# std            117.320187              3.982102         12.122151
# min            480.000000             11.000000        104.000000
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID              0
# Age                     0
# Gender                  0
# Heart_Rate_bpm          0
# SpO2_percent            0
# Body_Temperature_C      0
# ECG_RR_Interval_ms      0
# Respiration_Rate_bpm    0
# Systolic_BP_mmHg        0
# Diastolic_BP_mmHg       0
# Activity_Level          0
# AHI_Index_per_hour      0
# Apnea_Severity          0
# Model_Confidence        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(x='Apnea_Severity', data=df)
plt.show()

# %%
df['Apnea_Severity']
# Out:
# 0           Mild
# 1         Severe
# 2           Mild
# 3           Mild
# 4         Severe
#           ...
# 6495    Moderate
# 6496      Severe
# 6497      Severe
# 6498      Severe
# 6499      Normal
# Name: Apnea_Severity, Length: 6500, dtype: object

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=20)
plt.show()

# %%
sns.countplot(x='Gender', data=df)
plt.show()

# %%
sns.histplot(df['Heart_Rate_bpm'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.boxplot(y=df['Heart_Rate_bpm'])
plt.show()

# %%
sns.boxplot(x='Apnea_Severity',
            y='Heart_Rate_bpm',
            data=df)
plt.show()

# %%
sns.histplot(df['Model_Confidence'])
plt.show()
